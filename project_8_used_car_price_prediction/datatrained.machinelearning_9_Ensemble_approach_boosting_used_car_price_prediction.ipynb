# %% [markdown]
# # XGBOOST
#
# 1. The main advantages of XGBoost is its lightning speed compared to other algorithms
#
# 2. It uses parallel processing to increase the speed.
#
# 3. Sequential tree growing
#
# 4. However, XGBoost is more difficult to understand, visualize and to tune compared to AdaBoost and random forests.
#
# 5. XGBoost also handles missing values in the dataset. So, in data wrangling, you may or may not do a separate treatment for the missing values, because XGBoost is capable of handling missing values internally.
#
# 6. XGBoost is very popular because it has been the winning algorithm in a number of Kaggle competitions

# %%
# install xgboost before using
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\anand\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\anand\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\anand\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %% [markdown]
# # Used cars price prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# preprocessing
from sklearn.model_selection import train_test_split,GridSearchCV

# metrics and models
from sklearn.metrics import r2_score,mean_squared_error

import xgboost as xgb

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # read datasets
#
# # note-this file is in github but due to its size we have deleted some of the data to accomodate in the github

# %%
df=pd.read_csv('vehicles_data_students.csv')
df
# Out:
#        Unnamed: 0          id  price    year   manufacturer  \
# 0           55483  7315914053      0  2018.0            ram
# 1          162368  7310885048  13995  2017.0          mazda
# 2          234393  7308243856  19990  2019.0     mitsubishi
# 3          276110  7315817729      0  2019.0          honda
# 4          349033  7301620999  42900  2015.0      chevrolet
# ...           ...         ...    ...     ...            ...
# 64027      250960  7310954770   3495  1997.0        mercury
# 64028      217058  7305666517  25590  2018.0        lincoln
# 64029      323468  7316544829  22421  2015.0  mercedes-benz
# 64030      132003  7314796788  29999  2013.0           jeep
# 64031      296896  7309354482   8850  2015.0      chevrolet
#
#                           model  condition    cylinders    fuel  odometer  \
# 0                promaster 2500  excellent          NaN     gas   44244.0
# 1                          cx-3        NaN  4 cylinders     gas    7037.0
# 2              eclipse cross sp       good          NaN     gas   35313.0
# 3                          cr-v        NaN          NaN     gas   25626.0
# 4                      corvette  excellent  8 cylinders     gas   29000.0
# ...                         ...        ...          ...     ...       ...
# 64027             grand marquis       good  8 cylinders     gas  106253.0
# 64028  mkz reserve hybrid sedan       good          NaN  hybrid   33467.0
# 64029                   e-class  excellent          NaN     gas   55494.0
# 64030  wrangler unlimited sport        NaN          NaN     gas   63408.0
# 64031                     sonic  excellent  4 cylinders     gas  114248.0
#
#       title_status transmission drive         size         type paint_color  \
# 0            clean    automatic   NaN          NaN          van         NaN
# 1          rebuilt    automatic   NaN          NaN          SUV       white
# 2            clean        other   4wd          NaN    hatchback       white
# 3            clean    automatic   NaN          NaN          SUV      orange
# 4            clean    automatic   NaN          NaN  convertible       black
# ...            ...          ...   ...          ...          ...         ...
# 64027        clean    automatic   rwd          NaN        sedan       white
# 64028        clean        other   fwd          NaN        sedan       white
# 64029        clean    automatic   rwd          NaN        sedan       black
# 64030        clean    automatic   4wd          NaN          SUV       white
# 64031        clean    automatic   fwd  sub-compact        sedan       green
#
#        county state        lat        long
# 0         NaN    ca  32.792800 -116.966500
# 1         NaN    ia  41.207382  -96.023096
# 2         NaN    nc  35.190000  -80.830000
# 3         NaN    ny  40.854573  -74.120219
# 4         NaN    sc  34.755562  -82.906419
# ...       ...   ...        ...         ...
# 64027     NaN    nj  40.588352  -74.291039
# 64028     NaN    mn  44.010000  -92.470000
# 64029     NaN    or  45.504350 -122.532962
# 64030     NaN    id  43.619740 -116.294690
# 64031     NaN    oh  40.002779  -83.133361
#
# [64032 rows x 20 columns]

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'price',
#  'year',
#  'manufacturer',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'county',
#  'state',
#  'lat',
#  'long']

# %%
drop_columns=['Unnamed: 0','id','title_status','transmission', 'drive',  'lat','long','county']
df=df.drop(columns=drop_columns,axis=1)

# %%
df.shape
# Out:
# (64032, 12)

# %%
df.isna().sum()
# Out:
# price               0
# year              158
# manufacturer     2569
# model             802
# condition       26097
# cylinders       26511
# fuel              424
# odometer          669
# size            45841
# type            13785
# paint_color     19505
# state               0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#        price    year manufacturer                  model  condition  \
# 5          0  2006.0     chrysler                    300   like new
# 9      20995  2011.0    chevrolet         silverado 1500  excellent
# 30     13000  2012.0     infiniti                   g37x       good
# 32     12500  2017.0        buick  encore premium sport8   like new
# 39     44500  2015.0          gmc    yukon xl denali 4x4  excellent
# ...      ...     ...          ...                    ...        ...
# 64008   2150  2002.0    chevrolet                 blazer       fair
# 64010   3995  2003.0        acura                    mdx       good
# 64014  15850  2008.0         jeep                rubicon       good
# 64015   8999  2010.0        honda                odyssey       good
# 64031   8850  2015.0    chevrolet                  sonic  excellent
#
#          cylinders fuel  odometer         size   type paint_color state
# 5      8 cylinders  gas  149000.0    full-size  sedan       white    fl
# 9      8 cylinders  gas   92001.0     mid-size  truck        blue    wi
# 30     6 cylinders  gas   49200.0     mid-size  sedan       black    oh
# 32     4 cylinders  gas   73057.0     mid-size    SUV       black    ny
# 39     8 cylinders  gas   91000.0    full-size    SUV       white    az
# ...            ...  ...       ...          ...    ...         ...   ...
# 64008  6 cylinders  gas  151255.0     mid-size    SUV       black    oh
# 64010  6 cylinders  gas  161000.0    full-size    SUV       white    az
# 64014  6 cylinders  gas  151628.0      compact    SUV       green    wi
# 64015  6 cylinders  gas  125989.0    full-size    van        blue    pa
# 64031  4 cylinders  gas  114248.0  sub-compact  sedan       green    oh
#
# [12281 rows x 12 columns]

# %%
df.shape
# Out:
# (12281, 12)

# %%
df.describe()
# Out:
#               price          year      odometer
# count  1.228100e+04  12281.000000  1.228100e+04
# mean   1.441155e+04   2008.448416  1.274436e+05
# std    1.541625e+05     10.038207  2.827070e+05
# min    0.000000e+00   1918.000000  0.000000e+00
# 25%    4.950000e+03   2006.000000  7.312800e+04
# 50%    8.999000e+03   2011.000000  1.147000e+05
# 75%    1.699800e+04   2014.000000  1.562330e+05
# max    1.700000e+07   2021.000000  1.000000e+07

# %% [markdown]
# # check if there are any duolicates .remove if there are any duplicates

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        price    year manufacturer                  model  condition  \
# 5          0  2006.0     chrysler                    300   like new
# 9      20995  2011.0    chevrolet         silverado 1500  excellent
# 30     13000  2012.0     infiniti                   g37x       good
# 32     12500  2017.0        buick  encore premium sport8   like new
# 39     44500  2015.0          gmc    yukon xl denali 4x4  excellent
# ...      ...     ...          ...                    ...        ...
# 64008   2150  2002.0    chevrolet                 blazer       fair
# 64010   3995  2003.0        acura                    mdx       good
# 64014  15850  2008.0         jeep                rubicon       good
# 64015   8999  2010.0        honda                odyssey       good
# 64031   8850  2015.0    chevrolet                  sonic  excellent
#
#          cylinders fuel  odometer         size   type paint_color state
# 5      8 cylinders  gas  149000.0    full-size  sedan       white    fl
# 9      8 cylinders  gas   92001.0     mid-size  truck        blue    wi
# 30     6 cylinders  gas   49200.0     mid-size  sedan       black    oh
# 32     4 cylinders  gas   73057.0     mid-size    SUV       black    ny
# 39     8 cylinders  gas   91000.0    full-size    SUV       white    az
# ...            ...  ...       ...          ...    ...         ...   ...
# 64008  6 cylinders  gas  151255.0     mid-size    SUV       black    oh
# 64010  6 cylinders  gas  161000.0    full-size    SUV       white    az
# 64014  6 cylinders  gas  151628.0      compact    SUV       green    wi
# 64015  6 cylinders  gas  125989.0    full-size    van        blue    pa
# 64031  4 cylinders  gas  114248.0  sub-compact  sedan       green    oh
#
# [11694 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# price           0
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# size            0
# type            0
# paint_color     0
# state           0
# dtype: int64

# %% [markdown]
# # filter categorical features

# %%
#separate object data type columns
object_type_columns=list(df.select_dtypes(include='object'))
object_type_columns
# Out:
# ['manufacturer',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'size',
#  'type',
#  'paint_color',
#  'state']

# %%
# object_type_columns=list(object_columns.columns)
# object_type_columns

# %% [markdown]
# # encoding categorical columns using get_dummies.
# note-please visit encoder and imputer live class recordings for more information on get_dummies

# %%
df_dummies=pd.get_dummies(df[object_type_columns],drop_first=True)

# %%
df_dummies.head()
# Out:
#     manufacturer_alfa-romeo  manufacturer_audi  manufacturer_bmw  \
# 5                     False              False             False
# 9                     False              False             False
# 30                    False              False             False
# 32                    False              False             False
# 39                    False              False             False
#
#     manufacturer_buick  manufacturer_cadillac  manufacturer_chevrolet  \
# 5                False                  False                   False
# 9                False                  False                    True
# 30               False                  False                   False
# 32                True                  False                   False
# 39               False                  False                   False
#
#     manufacturer_chrysler  manufacturer_datsun  manufacturer_dodge  \
# 5                    True                False               False
# 9                   False                False               False
# 30                  False                False               False
# 32                  False                False               False
# 39                  False                False               False
#
#     manufacturer_ferrari  ...  state_sd  state_tn  state_tx  state_ut  \
# 5                  False  ...     False     False     False     False
# 9                  False  ...     False     False     False     False
# 30                 False  ...     False     False     False     False
# 32                 False  ...     False     False     False     False
# 39                 False  ...     False     False     False     False
#
#     state_va  state_vt  state_wa  state_wi  state_wv  state_wy
# 5      False     False     False     False     False     False
# 9      False     False     False      True     False     False
# 30     False     False     False     False     False     False
# 32     False     False     False     False     False     False
# 39     False     False     False     False     False     False
#
# [5 rows x 3508 columns]

# %%
df_dummies.shape
# Out:
# (11694, 3508)

# %%
df=df.join(df_dummies)

# %%
df.shape
# Out:
# (11694, 3520)

# %%
df.head()
# Out:
#     price    year manufacturer                  model  condition    cylinders  \
# 5       0  2006.0     chrysler                    300   like new  8 cylinders
# 9   20995  2011.0    chevrolet         silverado 1500  excellent  8 cylinders
# 30  13000  2012.0     infiniti                   g37x       good  6 cylinders
# 32  12500  2017.0        buick  encore premium sport8   like new  4 cylinders
# 39  44500  2015.0          gmc    yukon xl denali 4x4  excellent  8 cylinders
#
#    fuel  odometer       size   type  ... state_sd state_tn  state_tx  \
# 5   gas  149000.0  full-size  sedan  ...    False    False     False
# 9   gas   92001.0   mid-size  truck  ...    False    False     False
# 30  gas   49200.0   mid-size  sedan  ...    False    False     False
# 32  gas   73057.0   mid-size    SUV  ...    False    False     False
# 39  gas   91000.0  full-size    SUV  ...    False    False     False
#
#     state_ut  state_va  state_vt  state_wa  state_wi  state_wv  state_wy
# 5      False     False     False     False     False     False     False
# 9      False     False     False     False      True     False     False
# 30     False     False     False     False     False     False     False
# 32     False     False     False     False     False     False     False
# 39     False     False     False     False     False     False     False
#
# [5 rows x 3520 columns]

# %%
df.drop(columns=object_type_columns,axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    price    year  odometer  manufacturer_alfa-romeo  manufacturer_audi  \
# 5      0  2006.0  149000.0                    False              False
# 9  20995  2011.0   92001.0                    False              False
#
#    manufacturer_bmw  manufacturer_buick  manufacturer_cadillac  \
# 5             False               False                  False
# 9             False               False                  False
#
#    manufacturer_chevrolet  manufacturer_chrysler  ...  state_sd  state_tn  \
# 5                   False                   True  ...     False     False
# 9                    True                  False  ...     False     False
#
#    state_tx  state_ut  state_va  state_vt  state_wa  state_wi  state_wv  \
# 5     False     False     False     False     False     False     False
# 9     False     False     False     False     False      True     False
#
#    state_wy
# 5     False
# 9     False
#
# [2 rows x 3511 columns]

# %% [markdown]
# While practicing try other encoding techniques as well and compare the final accuracy.
#
# Selecting realistic data. Here Domain knowledge will help a lot to decide what could be the higher and lower price.
#
# Let's consider below prices in this example
#
#
#
#
# Devide dataset into features and label

# %%
df=df[df['price']>1000]
df=df[df['price']<25000]

# %%
df.shape
# Out:
# (9325, 3511)

# %% [markdown]
# # divide dataset into features and label

# %%
y=df['price']
X=df.drop(['price'],axis=1)

# %%
# data split into train test
train_X,test_x,train_Y,test_y=train_test_split(X,y,test_size=0.25,random_state=10)

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
xgb=xgb.XGBRFRegressor()
xgb.fit(train_X,train_Y)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, reg_alpha=None, ...)

# %%
y_pred=xgb.predict(test_x)

# %%
r2_score(test_y,y_pred)
# Out:
# 0.5511315388467979

# %% [markdown]
# Tune the parameters and check if you can increase the score
#
# Difference between Bagging and Boosting
#
# Boosting
#
#
#
# Training data subsets are drawn randomly with replacement from the entire training dataset.
#
#
#
# Bagging attempts to tackle the over-fitting issue.
#
# Every model receives an equal weight.
#
# Objective to decrease variance, not bias.
#
# Every model is built independently.
#
#
# Bagging
# Each new subset contains the components that were misclassified by previous models.
#
# Boosting tries to reduce bias.
#
# Models are weighted by their performance.
#
# Objective to decrease bias, not variance.
#
# New models are affected by the performance of the previously Ideveloped model.
